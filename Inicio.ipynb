# %%
import requests
import bs4

#1 obtener url
url = "https://books.toscrape.com/"
respuesta_obtenida = requests.get(url)
html_obtenido = respuesta_obtenida.text

#2 parsear ese html

primer_h3 = soup.find('h3')
print(primer_h3)
print(primer_h3.text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 import requests
# ----> 2 import bs4
#       4 #1 obtener url
#       5 url = "https://books.toscrape.com/"
#
# ModuleNotFoundError: No module named 'bs4'

# %%
# !pip install beautifulsoup4
from bs4 import BeautifulSoup
print("✅ BeautifulSoup está lista para parsear como una bestia.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 # !pip install beautifulsoup4
# ----> 2 from bs4 import BeautifulSoup
#       3 print("✅ BeautifulSoup está lista para parsear como una bestia.")
#
# ModuleNotFoundError: No module named 'bs4'

# %%
import requests
from bs4 import BeautifulSoup

# 1. Obtener la URL
url = "https://books.toscrape.com/"
respuesta_obtenida = requests.get(url)
html_obtenido = respuesta_obtenida.text  # HTML como string

# 2. Parsear ese HTML con BeautifulSoup
soup = BeautifulSoup(html_obtenido, 'html.parser')  # <- ¡ESTO FALTABA!

# 3. Buscar el primer título <h3>
primer_h3 = soup.find('h3')

# 4. Mostrar el contenido
print(primer_h3)         # Muestra todo el tag <h3>...</h3>
print(primer_h3.text)    # Muestra solo el texto (título del libro)
# Out:
# <h3><a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
# A Light in the ...
